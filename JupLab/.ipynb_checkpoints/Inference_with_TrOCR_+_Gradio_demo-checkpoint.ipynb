# %% [markdown]
# ## Set-up environment
#
# We install 🤗 Transformers, which includes many awesome models, including TrOCR by Microsoft Research.

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.9 MB 7.5 MB/s
#      |████████████████████████████████| 120 kB 51.7 MB/s
#      |████████████████████████████████| 6.6 MB 37.9 MB/s

# %% [markdown]
# ## Load image
#
# Here we load an image from private data, on which TrOCR was fine-tuned.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from PIL import Image

url0 = "https://fki.tic.heia-fr.ch/static/img/a01-122-02.jpg"
url  = "/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-001.jpg"
image = Image.open(url).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=775x128 at 0x7FC7CF96EB50>

# %%
# url2 = "/content/drive/MyDrive/TrsOCR _utorial/sample/img/RALK987_1865_817_120_001-001.jpg"
# # image = Image.open(requests.get(url2, stream=True).raw).convert("RGB")
# image2 = Image.open(url2)
# expacted_text = "Csengery|Antal|r.|t."
# import numpy
# a = numpy.array(image2)
# a.reshape(100, _ , 3)
# a.size

# %% [markdown]
# ## Prepare image for model
#
# Next, we use `TrOCRProcessor` (which wraps a `ViTFeatureExtractor` and a `RobertaTokenizer` into one) to resize + normalize the image for the model.

# %%
from transformers import TrOCRProcessor
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
# calling the processor is equivalent to calling the feature extractor
print(processor)
pixel_values = processor(image, return_tensors="pt").pixel_values
print(pixel_values.shape)
# Out:
# TrOCRProcessor:
# - feature_extractor: ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "size": 384
# }
#
# ...

# %% [markdown]
# ## Load model
#
# Here we load a TrOCR model from the [hub](https://huggingface.co/models?other=trocr). TrOCR models are instances of [`VisionEncoderDecoderModel`](https://huggingface.co/docs/transformers/model_doc/vision-encoder-decoder), which combine a vision encoder (like ViT, BEiT, DeiT, ...) with a language model as decoder (like BERT, RoBERTa, GPT-2, ...).

# %%
from pydantic import config
from transformers import (VisionEncoderDecoderModel ,
                          TrOCRConfig,
                          TrOCRForCausalLM,
                          ViTConfig,
                          ViTModel,)
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")
#  new 
# encoder = ViTModel(ViTConfig())
# decoder = TrOCRForCausalLM(TrOCRConfig())
# print(encoder.config.image_size)
# encoder.config.image_size = 384
# print(encoder.config.image_size)
# model2 = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder)
# Out:
# Downloading:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-handwritten and are newly initialized: ['encoder.pooler.dense.weight', 'encoder.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Generate text
#
# Finally, we can generate text autoregressively using the `.generate()` method. We use the tokenizer part of the `processor` to decode the generated id's back to text. Note that by default, greedy search is used for generation, but there are more fancy methods like beam search and top-k sampling, which are also supported. You can check out [this blog post](https://huggingface.co/blog/how-to-generate) for details.

# %%
# # new 
generated_ids = model.generate(pixel_values)
print(generated_ids)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1232: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# tensor([[    2, 16764,  2590,  2961,  3963,   748,     4,    90,     4,     2]])
# Chengering streak v.t.

# %% [markdown]
# ## Gradio demo
#
# We can also wrap up everything we wrote above in a quick [Gradio](https://gradio.app/) demo. Gradio is an awesome tool for creating quick ML demos!
#
# We just need to define a function that takes in an image input and produces a text output (note that Gradio supports many other input & output formats)!

# %%
# !pip install -q gradio
# Out:
#      |████████████████████████████████| 5.3 MB 3.9 MB/s
#      |████████████████████████████████| 84 kB 2.4 MB/s
#      |████████████████████████████████| 112 kB 60.2 MB/s
#      |████████████████████████████████| 270 kB 64.0 MB/s
#      |████████████████████████████████| 55 kB 3.4 MB/s
#      |████████████████████████████████| 57 kB 4.0 MB/s
#      |████████████████████████████████| 2.3 MB 54.5 MB/s
#      |████████████████████████████████| 54 kB 3.2 MB/s
#      |████████████████████████████████| 84 kB 3.6 MB/s
#      |████████████████████████████████| 212 kB 69.4 MB/s
#      |████████████████████████████████| 63 kB 2.1 MB/s
#      |████████████████████████████████| 80 kB 9.1 MB/s
#      |████████████████████████████████| 68 kB 6.0 MB/s
#      |████████████████████████████████| 43 kB 2.0 MB/s
#      |████████████████████████████████| 594 kB 40.9 MB/s
#      |████████████████████████████████| 4.0 MB 48.5 MB/s
#      |████████████████████████████████| 856 kB 71.1 MB/s
# ...

# %%
import gradio as gr
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
import requests
from PIL import Image

processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-handwritten and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import os
urls=[]
def getFiles(path):
    for file in os.listdir(path):
        # if file.endswith(".jpg"):
            urls.append(os.path.join(path, file))
    return urls

# %%
# filesPath = "/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img"
# getFiles(filesPath)
# urls[0]

# %%
# make new dir 
path = "/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/processed_img"
try:
  os.mkdir(path)
except:
  print('the dir already exist !!')
# Out:
# the dir already exist !!

# %%
# load image examples from the IAM database
# urls = ['https://fki.tic.heia-fr.ch/static/img/a01-122-02.jpg', 
#         'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU',
#         'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNYtTuSBpZPV_nkBYPMFwVVD9asZOPgHww4epu9EqWgDmXW--sE2o8og40ZfDGo87j5w&usqp=CAU',
#         ]
# load image examples from the hungarain  datasets 
# urls2 = ['/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-001.jpg',
#          '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-002.jpg',
#          '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-003.jpg',    
#         ]   
for idx, url in enumerate(urls):
  image = Image.open(url).convert("RGB")
  # image = Image.open(requests.get(url, stream=True).raw)
  name= f'/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/processed_img/image_{idx}.png'
  image.save(name)

# %%
def process_image(image):
    # prepare image
    pixel_values = processor(image, return_tensors="pt").pixel_values
    # generate (no beam search)
    generated_ids = model.generate(pixel_values)
    # decode
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return generated_text

# %%
title = "Interactive demo: TrOCR"
description = "Demo for Microsoft's TrOCR, an encoder-decoder model consisting of an image Transformer encoder and a text Transformer decoder for state-of-the-art optical character recognition (OCR) on single-text line images. This particular model is fine-tuned on IAM, a dataset of annotated handwritten images. To use it, simply upload an image or use the example image below and click 'submit'. Results will show up in a few seconds."
article = "<p style='text-align: center'><a href='https://arxiv.org/abs/2109.10282'>TrOCR: Transformer-based Optical Character Recognition with Pre-trained Models</a> | <a href='https://github.com/microsoft/unilm/tree/master/trocr'>Github Repo</a></p>"
# get new processed image 
filesPath = "/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/processed_img"
examples = getFiles(filesPath)
print(examples[0])

# examples =[["image_0.png"], ["image_1.png"], ["image_2.png"]]
examples_ = examples[:3]
iface = gr.Interface(fn=process_image, 
                     inputs=gr.inputs.Image(type="pil"), 
                     outputs=gr.outputs.Textbox(),
                     title=title,
                     description=description,
                     article=article,
                     examples=examples_)
iface.launch(debug=True)
# Out:
# /content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_143_001-010.jpg
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# ...

# %%
examples[:3]
# Out:
# ['/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_143_001-010.jpg',
#  '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_160_001-015.jpg',
#  '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_297_003-021.jpg']

# %%
# very important 
# Vit  ,BEit as encoder and GPT-2 , BERT, RoBERTa decoder  
# https://programtalk.com/vs4/python/huggingface/transformers/src/transformers/models/vision_encoder_decoder/modeling_flax_vision_encoder_decoder.py/
# useful for leteretire review 
# https://qiita.com/relu/items/c027c486758525c0b6b9
# Deit encoder and RoBerta decoder 
# https://bytemeta.vip/repo/aws/aws-neuron-sdk/issues/410
# T5 is text to text trnsformers

# %% [markdown]
# https://programtalk.com/python-more-examples/transformers.TrOCRForCausalLM/

# %%
from transformers import (
    TrOCRConfig,
    TrOCRProcessor,
    TrOCRForCausalLM,
    ViTConfig,
    ViTModel,
    VisionEncoderDecoderModel,
)
import requests
import cv2
from PIL import Image

# TrOCR is a decoder model and should be used within a VisionEncoderDecoderModel
# init vision2text model with random weights
encoder = ViTModel(ViTConfig())
decoder = TrOCRForCausalLM(TrOCRConfig())
model = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder)

# If you want to start from the pretrained model, load the checkpoint with `VisionEncoderDecoderModel`
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
# model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")
tokenizer=processor.feature_extractor
# load image from the IAM dataset
# url = "https://fki.tic.heia-fr.ch/static/img/a01-122-02.jpg"
url = '/content/image_0.png'
image = Image.open(url).convert("RGB")
# image normlize with 224 x 224
# image_0 = cv2.imread('/content/mm.png')
pixel_values = processor(image, return_tensors="pt").pixel_values
text = "industry, ' Mr. Brown commented icily. ' Let us have a"

# training
model.config.decoder_start_token_id = processor.tokenizer.cls_token_id
model.config.pad_token_id = processor.tokenizer.pad_token_id
model.config.vocab_size = model.config.decoder.vocab_size
# model.config.encoder.image_size = 224
# model.config.image_size  = 384
labels = processor.tokenizer(text, return_tensors="pt").input_ids
outputs = model(pixel_values, labels=labels)
loss = outputs.loss
round(loss.item(), 2)

# inference
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
generated_text
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-01c4edce2898> in <module>
#      37 # model.config.image_size  = 384
#      38 labels = processor.tokenizer(text, return_tensors="pt").input_ids
# ---> 39 outputs = model(pixel_values, labels=labels)
#      40 loss = outputs.loss
#      41 round(loss.item(), 2)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ...

# %% [markdown]
# [link text](https://github.com/win5923/TrOCR-Handwritten-Mathematical-Expression-Recognition)
#
# [link text](https://colab.research.google.com/github/eugenesiow/practical-ml/blob/master/notebooks/OCR_from_Images_with_Transformers.ipynb#scrollTo=SePiVWCp2FKv)
# [compete colab like hun](https://colab.research.google.com/github/NielsRogge/Transformers-Tutorials/blob/master/TrOCR/Fine_tune_TrOCR_on_IAM_Handwriting_Database_using_Seq2SeqTrainer.ipynb)

# %%
model.config

# %%
dict_ = processor.__dict__
a = dict_['feature_extractor']
print(type(a)) ,print(a.size)
a
# Out:
# <class 'transformers.models.vit.feature_extraction_vit.ViTFeatureExtractor'>
# 384
# ViTFeatureExtractor {
#   "do_normalize": true,
#   "do_resize": true,
#   "feature_extractor_type": "ViTFeatureExtractor",
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "size": 384
# }

# %%
processor.feature_extractor.size
model.config.encoder.image_size
model.config.decoder

# %%
# type(processor), processor.feature_extractor.ViTFeatureExtractor
processor.__dict__

# %%
# Resize Image 
import cv2 
image_0 = cv2.imread('/content/mm.png')
image_0.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# ##  Vit as Encoder and GPT-2 as Decoder

# %%
from transformers import (
    GPT2Model, 
    GPT2Config,
    TrOCRProcessor,
    ViTConfig,
    ViTModel,
    VisionEncoderDecoderModel,
)
import requests
import cv2
from PIL import Image

# TrOCR is a decoder model and should be used within a VisionEncoderDecoderModel
# init vision2text model with random weights
# encoder = ViTModel(ViTConfig())
# decoder = GPT2Model(GPT2Config())
# model = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder)

# If you want to start from the pretrained model, load the checkpoint with `VisionEncoderDecoderModel`
# processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
processor = TrOCRProcessor.from_pretrained('/content/drive/MyDrive/TrsOCR_utorial/Models/Arany200')
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# load image from the IAM dataset
# url = "https://fki.tic.heia-fr.ch/static/img/a01-122-02.jpg"
# image = Image.open(requests.get(url, stream=True).raw).convert("RGB")
url = '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-001.jpg'
image = Image.open(url).convert("RGB")
# image normlize with 224 x 224
# image_0 = cv2.imread('/content/mm.png')
pixel_values = processor(image, return_tensors="pt").pixel_values
text = "Csengery Antal r.t"

# training
model.config.decoder_start_token_id = processor.tokenizer.cls_token_id
model.config.pad_token_id = processor.tokenizer.pad_token_id
model.config.vocab_size = model.config.decoder.vocab_size
# model.config.encoder.image_size = 224
# model.config.image_size  = 384
labels = processor.tokenizer(text, return_tensors="pt").input_ids
outputs = model(pixel_values, labels=labels)
loss = outputs.loss
round(loss.item(), 2)

# inference
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
generated_text
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-c7314e707243> in <module>
#      19 # If you want to start from the pretrained model, load the checkpoint with `VisionEncoderDecoderModel`
#      20 # processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
# ---> 21 processor = TrOCRProcessor.from_pretrained('/content/drive/MyDrive/TrsOCR_utorial/Models/Arany200')
#      22 model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")
#      23
#
# /usr/local/lib/python3.7/dist-packages/transformers/processing_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     180                 [`~tokenization_utils_base.PreTrainedTokenizer.from_pretrained`].
#     181         """
# --> 182         args = cls._get_arguments_from_pretrained(pretrained_model_name_or_path, **kwargs)
# ...

# %%
model.config.encoder

# %%
model.config.decoder
# Handwritten Text Recognition Using Deep Learning and Translate other longuage then convert to voice
#

# %%
from transformers import (
    RobertaConfig, 
    RobertaModel,
    BeitConfig,
    BeitModel,
    VisionEncoderDecoderModel,
    TrOCRProcessor,
)
import requests
from PIL import Image

# TrOCR is a decoder model and should be used within a VisionEncoderDecoderModel
# init vision2text model with random weights
encoder = BeitModel(BeitConfig())
decoder = RobertaModel(RobertaConfig())
model = VisionEncoderDecoderModel(encoder=encoder, decoder=decoder)

# If you want to start from the pretrained model, load the checkpoint with `VisionEncoderDecoderModel`
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
# model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# load image from the IAM dataset
url = '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/img/RALK987_1865_817_120_001-001.jpg'
image = Image.open(url).convert("RGB")
pixel_values = processor(image, return_tensors="pt").pixel_values
text = "Csengery Antal r.t"

# training
model.config.decoder_start_token_id = processor.tokenizer.cls_token_id
model.config.pad_token_id = processor.tokenizer.pad_token_id
model.config.vocab_size = model.config.decoder.vocab_size

labels = processor.tokenizer(text, return_tensors="pt").input_ids
outputs = model(pixel_values, labels=labels)
loss = outputs.loss
round(loss.item(), 2)

# inference
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
generated_text

# %%
# import gradio as gr
# what was used in DHLab
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
import glob
import sys
import cv2

impath = '/content/drive/MyDrive/TrsOCR_utorial/training-data-ex/processed_img/image_0.png'
image = cv2.imread(impath)

processor = TrOCRProcessor.from_pretrained("microsoft/trocr-large-handwritten")
# 4.5% CER, 20.0% WER
#model = VisionEncoderDecoderModel.from_pretrained(modelp).cuda()
model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(
                                 "microsoft/trocr-large-handwritten", "urduhack/roberta-urdu-small")

# prepare image
pixel_values = processor(image, return_tensors="pt").pixel_values

# generate (no beam search)
generated_ids = model.generate(inputs=pixel_values.cuda(), max_length=50,
                               num_beams=5,
                               early_stopping=True)

# decode
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(generated_text)
# Out:
# Downloading:   0%|          | 0.00/228 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-f1779803fb31> in <module>
#      12 #model = VisionEncoderDecoderModel.from_pretrained(modelp).cuda()
#      13 model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(
# ---> 14                                  "microsoft/trocr-large-handwritten", "urduhack/roberta-urdu-small")
#      15
#      16 # prepare image
#
# ...
